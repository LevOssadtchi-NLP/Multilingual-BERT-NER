# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/Multilingual-BERT-NER/src/
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Multilingual-BERT-NER/src/'
# /content/drive/MyDrive/Multilingual-BERT-NER/src

# %%
# !ls
# Out:
# dataset.py  eval.py  model.py  __pycache__  train.py

# %%
# !python train.py
# Out:
# tokenizer_config.json: 100% 49.0/49.0 [00:00<00:00, 385kB/s]
# vocab.txt: 100% 996k/996k [00:00<00:00, 13.1MB/s]
# tokenizer.json: 100% 1.96M/1.96M [00:00<00:00, 42.4MB/s]
# config.json: 100% 625/625 [00:00<00:00, 7.60MB/s]
# 2025-09-01 18:35:16.008733: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-01 18:35:16.027609: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756751716.046017    6683 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !pip install seqeval
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=cfb2b9f6df76e3a19230310f6a9aae86260777aa0a4720a5baa5c5cbaa85cf8f
#   Stored in directory: /root/.cache/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# ...

# %%
# !python eval.py
# Out:
# 2025-09-01 19:32:02.906686: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-01 19:32:02.925092: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756755122.947168   21484 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756755122.953736   21484 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
